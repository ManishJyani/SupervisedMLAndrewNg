# %% [markdown]
# # C1_W3_Lab01_Classification_Soln
# In this lab, you will contrast regression and classification.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.array([0., 1, 2, 3, 4, 5]) #single variable input
y_train = np.array([0,  0, 0, 1, 1, 1])
X_train2 = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]]) # 2 variable input
y_train2 = np.array([0, 0, 0, 1, 1, 1])

# %%
pos=y_train==1
neg= y_train==0

pos2= y_train2==1
neg2= y_train2==0
fig, ax = plt.subplots(1,2,figsize=(10,3))
ax[0].scatter(x_train[pos],y_train[pos],c='b',marker='o',label='y=1')
ax[0].scatter(x_train[neg],y_train[neg],c='r',marker='x',label='y=0')
ax[0].set_title("One Varialble")
ax[0].set_xlabel('X')
ax[0].set_ylabel("Y")
ax[0].legend()
ax[1].scatter(X_train2[pos2][:,0],X_train2[pos2][:,1],c='b',marker='o',label='y=1')
ax[1].scatter(X_train2[neg2][:,0],X_train2[neg2][:,1],c='r',marker='x',label='y=0')
ax[1].set_title("Two Varialble")
ax[1].set_xlabel("$X_1$")
ax[1].set_ylabel("$X_2$")
plt.tight_layout()
ax[1].legend()

# fig.show()

# %%
# above example seems like breast cancer , benign, malignant

# %%
# Nothing much in this lab , Reason why linear regression is bad is below image

# %% [markdown]
#  Outlier input may lead to very wrong prediction , like in below image
#
# <img align="left" src="images/linearRegrssionBad.png"     style=" width:500px; padding: 20px; " >

# %% [markdown]
# # C1_W3_Lab02_Sigmoid_function_Soln
# In this ungraded lab, we will
# - explore the sigmoid function (also known as the logistic function)
# - explore logistic regression; which uses the sigmoid function

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# z = fx+ b , this z is the input for the sigmoid function

def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
z_temp= np.arange(-10,11)
y= sigmoid(z_temp)

# %%
plt.plot(z_temp,y)

# %% [markdown]
# # C1_W3_Lab03_Decision_Boundary_Soln
# In this lab, we will:
# - Plot the decision boundary for a logistic regression model. This will give you a better sense of what the model is predicting.

# %%
X = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y = np.array([0, 0, 0, 1, 1, 1])

# %%
pos= y==0
neg= y==1

fig,ax= plt.subplots(1,1,figsize=(4,4))
ax.scatter(X[:,0][pos],X[:,1][pos],c='r',marker='x')
ax.scatter(X[:,0][neg],X[:,1][neg],c='b',marker='o')
ax.set_xlabel("$X_1$")
ax.set_ylabel("$X_2$")
# Out:
# Text(0, 0.5, '$X_2$')

# %%
# Out:
# array([0.5, 1. , 1.5])

# %%
# Choose values between 0 and 6
x0 = np.arange(0,6)

x1 = 3 - x0
fig,ax = plt.subplots(1,1,figsize=(5,4))
# Plot the decision boundary
ax.plot(x0,x1, c="b")
ax.axis([0, 4, 0, 3.5])

# Fill the region below the line
ax.fill_between(x0,x1, alpha=0.2)

# Plot the original data
# plot_data(X,y,ax)
ax.set_ylabel(r'$x_1$')
ax.set_xlabel(r'$x_0$')
plt.show()

# %%
# linear boundary with 2 variable in left negartive and right positive
